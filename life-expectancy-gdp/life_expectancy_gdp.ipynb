# %% [markdown]
# # Life Expectancy and GDP
#
# For this project, you will analyze data on GDP and life expectancy from the World Health Organization and the World Bank to try and identify the relationship between the GDP and life expectancy of six countries.
#
# During this project, you will analyze, prepare, and plot data in order to answer questions in a meaningful way.
#
# After you perform your analysis, you’ll be creating a blog post to share your findings on the World Health Organization website.

# %%
import pandas as pd

data = pd.read_csv('all_data.csv')
data.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB
#               Year  Life expectancy at birth (years)           GDP
# count    96.000000                         96.000000  9.600000e+01
# mean   2007.500000                         72.789583  3.880499e+12
# std       4.633971                         10.672882  5.197561e+12
# min    2000.000000                         44.300000  4.415703e+09
# 25%    2003.750000                         74.475000  1.733018e+11
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Has life expectancy increased over time in the six nations?
sns.lineplot(x='Year', y='Life expectancy at birth (years)', hue='Country', data=data)
plt.show()
plt.clf()
# Out:
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Has GDP increased over time in the six nations?
sns.lineplot(x='Year', y='GDP', hue='Country', data=data)
plt.show()
plt.clf()
# Out:
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Is there a correlation between GDP and life expectancy of a country?
sns.scatterplot(x='GDP', y='Life expectancy at birth (years)', data=data, hue='Country')
plt.show()
plt.clf()
# Out:
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# What is the average life expectancy in these nations?
ax = sns.boxplot(x='Country', y='Life expectancy at birth (years)', data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.show()
plt.clf()
# Out:
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# What is the distribution of that life expectancy?
ax = sns.histplot(x='Life expectancy at birth (years)', data=data)
plt.show()
plt.clf()
# Out:
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/dennisgera/.pyenv/versions/3.11.2/envs/ds-projects-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# predict the life expectancy in 2020 for these six countries.
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = data[['Year', 'GDP']]
y = data[['Life expectancy at birth (years)']]
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)
print(X_train.shape)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# (76, 2)
# [[68.50685763]
#  [83.5983744 ]
#  [81.01918981]
#  [71.68183977]
#  [70.14799489]
#  [85.06991889]
#  [79.16781399]
#  [73.25203775]
#  [68.55865649]
#  [70.92410357]
#  [75.9984189 ]
#  [79.29945673]
#  [70.02488001]
#  [69.47941924]
#  [79.94956588]
#  [75.20513441]
#  [71.41207564]
#  [71.8628496 ]
#  [70.26405337]
#  [69.63770785]]

# %%
# What is the mean squared error of our model?
from sklearn.metrics import mean_squared_error

print(mean_squared_error(y_test, y_pred))

# compare the predictions with the actual values by creating a scatter plot.
plt.scatter(y_test, y_pred)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()
plt.clf()

# plot the residuals to see if there are any patterns.
residuals = y_test - y_pred
plt.scatter(y_test, residuals)
plt.xlabel('Actual values')
plt.ylabel('Residuals')
plt.show()
plt.clf()
# Out:
# 91.03584749109979

# %%
# get the correlation of GDP and Life expectancy for each country.
correlations = data.groupby('Country').corr()
correlations
# Out:
#                                                                Year  \
# Country
# Chile                    Year                              1.000000
#                          Life expectancy at birth (years)  0.980543
#                          GDP                               0.962289
# China                    Year                              1.000000
#                          Life expectancy at birth (years)  0.982734
#                          GDP                               0.969447
# Germany                  Year                              1.000000
#                          Life expectancy at birth (years)  0.987377
#                          GDP                               0.894334
# Mexico                   Year                              1.000000
#                          Life expectancy at birth (years)  0.950451
#                          GDP                               0.937087
# United States of America Year                              1.000000
# ...
